# %%
import os
import re
import time
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from pybtex.database.input import bibtex

# Counting
import string
import nltk
from pattern.text.en import singularize, pluralize, lemma
from collections import Counter

# %%
# Open a bibtex file
parser = bibtex.Parser()
bibdata = parser.parse_file("chi.bib")

# Loop through the individual references
df = None
entry_list = []
for bib_id in bibdata.entries:
    b = bibdata.entries[bib_id].fields
    p = bibdata.entries[bib_id].persons
    
    if df is None:
        df = pd.DataFrame(columns=list(b.keys()) + ["author"])
    
    entry = dict(b)
    try:
        b["author"] = ", " .join([" ".join(name.first_names + name.last_names) for name in p["author"]])
        # df = df.append(dict(b), ignore_index=True)
        entry_list.append(b)
    except KeyError:
        continue

df = pd.DataFrame(entry_list)
df.head()
# Out:
#                                             abstract            address  \
# 0  HCI is increasingly concerned with health info...  New York, NY, USA
# 1  Online harm is a prevalent issue in adolescent...  New York, NY, USA
# 2  In this paper we present Immersive Speculative...  New York, NY, USA
# 3  Making time estimates, such as how long a give...  New York, NY, USA
# 4  Developers perform online sensemaking on a dai...  New York, NY, USA
#
#   articleno                                             author  \
# 0        43                 Naveena Karusala, Richard Anderson
# 1       146         Sijia Xiao, Coye Cheshire, Niloufar Salehi
# 2        17  Adalberto Simeone, Robbe Cools, Stan Depuydt, ...
# 3        30                       Morgane Koval, Yvonne Jansen
# 4        68             Michael Liu, Aniket Kittur, Brad Myers
#
#                                            booktitle                      doi  \
# 0  Proceedings of the 2022 CHI Conference on Huma...  10.1145/3491102.3517622
# 1  Proceedings of the 2022 CHI Conference on Huma...  10.1145/3491102.3517614
# 2  Proceedings of the 2022 CHI Conference on Huma...  10.1145/3491102.3517492
# 3  Proceedings of the 2022 CHI Conference on Huma...  10.1145/3491102.3502010
# 4  Proceedings of the 2022 CHI Conference on Huma...  10.1145/3491102.3501968
#
#             isbn                                           keywords  \
# 0  9781450391573  social media, misinformation, health informati...
# 1  9781450391573  online governance, content moderation, Online ...
# 2  9781450391573  Space Exploration., Virtual Reality, Speculati...
# 3  9781450391573         Planning fallacy, predictive visualization
# 4  9781450391573  Behavior patterns, Implicit signals, Decision ...
#
#                location numpages pages                            publisher  \
# 0  New Orleans, LA, USA       14   NaN  Association for Computing Machinery
# 1  New Orleans, LA, USA       15   NaN  Association for Computing Machinery
# 2  New Orleans, LA, USA       20   NaN  Association for Computing Machinery
# 3  New Orleans, LA, USA       19   NaN  Association for Computing Machinery
# 4  New Orleans, LA, USA       16   NaN  Association for Computing Machinery
#
#     series                                              title  \
# 0  CHI '22  Towards Conviviality in NavigatingHealth Infor...
# 1  CHI '22  Sensemaking, Support, Safety, Retribution, Tra...
# 2  CHI '22  Immersive Speculative Enactments: Bringing Fut...
# 3  CHI '22  Do You See What You Mean? Using Predictive Vis...
# 4  CHI '22  Crystalline: Lowering the Cost for Developers ...
#
#                                        url  year
# 0  https://doi.org/10.1145/3491102.3517622  2022
# 1  https://doi.org/10.1145/3491102.3517614  2022
# 2  https://doi.org/10.1145/3491102.3517492  2022
# 3  https://doi.org/10.1145/3491102.3502010  2022
# 4  https://doi.org/10.1145/3491102.3501968  2022

# %%
# Filter out by number of pages.
df["numpages"] = df["numpages"].fillna("0").astype(int)
short_paper_mask = df["numpages"] < 5

# Dropping short papers.
df = df.drop(df[df["numpages"] < 5].index, axis="index")
print("{} short papers are dropped.".format(np.sum(short_paper_mask)))

df.head()
# Out:
# 230 short papers are dropped.
#                                             abstract            address  \
# 0  HCI is increasingly concerned with health info...  New York, NY, USA
# 1  Online harm is a prevalent issue in adolescent...  New York, NY, USA
# 2  In this paper we present Immersive Speculative...  New York, NY, USA
# 3  Making time estimates, such as how long a give...  New York, NY, USA
# 4  Developers perform online sensemaking on a dai...  New York, NY, USA
#
#   articleno                                             author  \
# 0        43                 Naveena Karusala, Richard Anderson
# 1       146         Sijia Xiao, Coye Cheshire, Niloufar Salehi
# 2        17  Adalberto Simeone, Robbe Cools, Stan Depuydt, ...
# 3        30                       Morgane Koval, Yvonne Jansen
# 4        68             Michael Liu, Aniket Kittur, Brad Myers
#
#                                            booktitle                      doi  \
# 0  Proceedings of the 2022 CHI Conference on Huma...  10.1145/3491102.3517622
# 1  Proceedings of the 2022 CHI Conference on Huma...  10.1145/3491102.3517614
# 2  Proceedings of the 2022 CHI Conference on Huma...  10.1145/3491102.3517492
# 3  Proceedings of the 2022 CHI Conference on Huma...  10.1145/3491102.3502010
# 4  Proceedings of the 2022 CHI Conference on Huma...  10.1145/3491102.3501968
#
#             isbn                                           keywords  \
# 0  9781450391573  social media, misinformation, health informati...
# 1  9781450391573  online governance, content moderation, Online ...
# 2  9781450391573  Space Exploration., Virtual Reality, Speculati...
# 3  9781450391573         Planning fallacy, predictive visualization
# 4  9781450391573  Behavior patterns, Implicit signals, Decision ...
#
#                location  numpages pages                            publisher  \
# 0  New Orleans, LA, USA        14   NaN  Association for Computing Machinery
# 1  New Orleans, LA, USA        15   NaN  Association for Computing Machinery
# 2  New Orleans, LA, USA        20   NaN  Association for Computing Machinery
# 3  New Orleans, LA, USA        19   NaN  Association for Computing Machinery
# 4  New Orleans, LA, USA        16   NaN  Association for Computing Machinery
#
#     series                                              title  \
# 0  CHI '22  Towards Conviviality in NavigatingHealth Infor...
# 1  CHI '22  Sensemaking, Support, Safety, Retribution, Tra...
# 2  CHI '22  Immersive Speculative Enactments: Bringing Fut...
# 3  CHI '22  Do You See What You Mean? Using Predictive Vis...
# 4  CHI '22  Crystalline: Lowering the Cost for Developers ...
#
#                                        url  year
# 0  https://doi.org/10.1145/3491102.3517622  2022
# 1  https://doi.org/10.1145/3491102.3517614  2022
# 2  https://doi.org/10.1145/3491102.3517492  2022
# 3  https://doi.org/10.1145/3491102.3502010  2022
# 4  https://doi.org/10.1145/3491102.3501968  2022

# %%
# Count authors in total.
names, counts = np.unique(", ".join(df.author.tolist()).split(", "), return_counts=True)
df_author_counts = pd.DataFrame(
    {
        "author": names,
        "counts": counts
    }
)
df_author_counts = df_author_counts.sort_values(by="counts", ascending=False).reset_index(drop=True)
df_author_counts.index = np.arange(1, len(df_author_counts) + 1)

# Get top authors.
top_number = 50
top_authors = df_author_counts.head(top_number).author.tolist()
top_author_counts = df_author_counts.head(top_number).counts.tolist()
top_author_with_number = ["{:>2d} - {}".format(i, author) for i, author in zip(range(1, top_number+1), top_authors)]
print(top_authors)

# Plot.
fig, ax = plt.subplots(dpi=150, figsize=(5, 15))
ax.set_xlabel("Author")
ax.set_ylabel("Total publications")
# df_author_counts.head(top_number).set_index("author").plot.barh(ax=ax)
ax.barh(top_author_with_number, top_author_counts)
ax.invert_yaxis()
# Out:
# ['Juho Kim', 'Pablo Cesar', 'Munmun De Choudhury', 'Max M\\"{u}hlh\\"{a}user', 'Enrico Rukzio', 'Jessica Hammer', 'Neha Kumar', 'Florian Alt', 'Fangtian Ying', 'Josh Andres', 'Antonio Kr\\"{u}ger', 'Dilrukshi Gamage', 'Joni Salminen', 'Florian Mueller', 'Florian M\\"{u}ller', 'Pedro Lopes', 'Xiaojuan Ma', 'Katta Spiel', 'Kathrin Gerling', 'Albrecht Schmidt', 'Eduardo Velloso', "Pawe\\l{} Wo\\'{z}niak", 'Cheng Yao', 'Regan Mandryk', 'Joonhwan Lee', 'Yuanchun Shi', 'Pattie Maes', 'Guanyun Wang', 'Lining Yao', 'Bernard Jansen', 'Andrea Parker', 'Martin Schmitz', 'Benjamin Cowan', 'Rainer Malaka', 'Miriam Sturdee', 'Kristen Shinohara', 'Mary Czerwinski', 'Wendy Ju', 'Patrick Olivier', 'Soon-Gyo Jung', 'Yang Li', 'Mingming Fan', 'Benjamin Bach', 'Nicola Dell', 'Jan Gugenheimer', 'Florian Daiber', 'Andrii Matviienko', 'Chun Yu', 'Per Kristensson', 'Tilman Dingler']

# %%
df_author_counts[df_author_counts["author"].isin(["Jarrod Knibbe", "Vassilis Kostakos", "Jorge Goncalves"])]
# Out:
#                 author  counts
# 77     Jorge Goncalves       6
# 172  Vassilis Kostakos       5
# 889      Jarrod Knibbe       2

# %%
df_author_counts[df_author_counts.author.str.contains("Eduardo")]
# Out:
#                   author  counts
# 1533     Eduardo Velloso       8
# 1532       Eduardo Nebot       1
# 1531  Eduardo Gomez Ruiz       1

# %%
# Get author's publication by year. 
target_authors = top_authors[:5] + ["Eduardo Velloso"]

# Init plot.
fig, ax = plt.subplots(dpi=150)
ax.set_ylim([0, 10])
ax.set_xlabel("Year")
ax.set_ylabel("Publication count")

for target_author in target_authors:
    df_author = df[df.author.str.contains(target_author)]
    ax.plot(df_author.groupby("year").title.count(), 
            label=target_author, ls="-", marker="x", alpha=0.5)
ax.legend(bbox_to_anchor=(1, 1))
# Out:
# C:\Users\unime\AppData\Local\Temp\ipykernel_28984\1224243616.py:12: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax.plot(df_author.groupby("year").title.count(),

# %%
# Keywords analysis.
list_df_keyword_counts = []

for year in np.sort(df.year.unique()):
    
    # Slicing and counting.
    df_year = df[df.year == year].dropna(subset=["keywords"])
    all_year_keywords = ", ".join(df_year.keywords.tolist())
    all_year_keywords = [keyword.strip() for keyword in all_year_keywords.lower().split(",")]
    keywords, counts = np.unique(all_year_keywords, return_counts=True)

    # Make dataframe
    df_keyword_counts = pd.DataFrame(
        {
            "keyword": keywords,
            "keyword_count": counts,
            "year": year
        }
    )
    df_keyword_counts = df_keyword_counts.sort_values(by="keyword_count", ascending=False).head(10)
    
    # Appending.
    list_df_keyword_counts.append(df_keyword_counts)

# Collating.
df_keyword_counts = pd.concat(list_df_keyword_counts)
df_keyword_counts.head(10)
# Out:
#                       keyword  keyword_count  year
# 1375          virtual reality             25  2020
# 111         augmented reality             18  2020
# 18              accessibility             17  2020
# 342                    design             13  2020
# 184                  children             12  2020
# 600                       hci             11  2020
# 991                   privacy             11  2020
# 90    artificial intelligence             11  2020
# 98       assistive technology             10  2020
# 1336          user experience             10  2020

# %%
# Draw a nested barplot
g = sns.catplot(aspect=1.5,
    data=df_keyword_counts, kind="bar",
    x="year", y="keyword_count", hue="keyword",
    palette="dark", alpha=.6, height=6
)
g.despine(left=True)
g.set_axis_labels("Year", "Counts")
g.figure.suptitle("Keyword counts")
g.legend.set_title("")

# %%
# Title analysis.
list_df_title_counts = []

for year in np.sort(df.year.unique()):
    
    # Slicing.
    df_year = df[df.year == year].dropna(subset=["title"])

    # Preprocessing.
    combined_text = " ".join(df_year.title).lower()
    # Remove punctuation.
    combined_text.translate(str.maketrans("", "", string.punctuation))
    # Remove prepositions, conjunctions, etc. 
    tokens = nltk.word_tokenize(combined_text)
    tagged = nltk.pos_tag(tokens)
    black_list = ["%", "result",]
    white_list = ["NN", "NNS", "NNP", "NNPS"]
    filtered = list(filter(lambda x: x[1] in white_list, tagged))
    filtered = [token[0] for token in filtered]
    filtered = list(filter(lambda x: x not in black_list, filtered))
    filtered = [singularize(word) for word in filtered]

    # Counting and sorting.
    wordcount = Counter(filtered)
    ser_wordcount = pd.Series(wordcount)
    ser_wordcount = ser_wordcount.sort_values(ascending=False)
    

    # Make dataframe
    df_title_counts = pd.DataFrame(
        {
            "word": ser_wordcount.index,
            "word_count": ser_wordcount.values,
            "year": year
        }
    )
    df_title_counts = df_title_counts.sort_values(by="word_count", ascending=False).iloc[10:20]
    
    # Appending.
    list_df_title_counts.append(df_title_counts)

# Collating.
df_title_counts = pd.concat(list_df_title_counts)
df_title_counts = df_title_counts.drop(df_title_counts[df_title_counts.word == "”"].index)
df_title_counts.head(10)
# Out:
#           word  word_count  year
# 9         hcus          13  2020
# 10       child          13  2020
# 12    approach          12  2020
# 13      effect          12  2020
# 14        user          11  2020
# 15      person          11  2020
# 20  evaluation           9  2020
# 22   interface           9  2020
# 21       datum           9  2020
# 17  perception           9  2020

# %%
# Draw a nested barplot
g = sns.catplot(aspect=1.5,
    data=df_title_counts, kind="bar",
    x="year", y="word_count", hue="word",
    palette="dark", alpha=.6, height=6
)
g.despine(left=True)
g.set_axis_labels("Year", "Counts")
g.legend.set_title("")
g.figure.suptitle("Title word frequencies")
# Out:
# Text(0.5, 0.98, 'Title word frequencies')

# %%
# Abstract analysis.
list_df_abstract_counts = []

for year in np.sort(df.year.unique()):
    
    # Slicing.
    df_year = df[df.year == year].dropna(subset=["abstract"])

    # Preprocessing.
    combined_text = " ".join(df_year.abstract).lower()
    # Remove punctuation.
    combined_text.translate(str.maketrans("", "", string.punctuation))
    # Remove prepositions, conjunctions, etc. 
    tokens = nltk.word_tokenize(combined_text)
    tagged = nltk.pos_tag(tokens)
    black_list = ["%", "result",]
    white_list = ["NN", "NNS", "NNP", "NNPS"]
    filtered = list(filter(lambda x: x[1] in white_list, tagged))
    filtered = [token[0] for token in filtered]
    filtered = list(filter(lambda x: x not in black_list, filtered))
    filtered = [singularize(word) for word in filtered]

    # Counting and sorting.
    wordcount = Counter(filtered)
    ser_wordcount = pd.Series(wordcount)
    ser_wordcount = ser_wordcount.sort_values(ascending=False)
    

    # Make dataframe
    df_abstract_counts = pd.DataFrame(
        {
            "word": ser_wordcount.index,
            "word_count": ser_wordcount.values,
            "year": year
        }
    )
    df_abstract_counts = df_abstract_counts.sort_values(by="word_count", ascending=False).head(10)
    
    # Appending.
    list_df_abstract_counts.append(df_abstract_counts)

# Collating.
df_abstract_counts = pd.concat(list_df_abstract_counts)
df_abstract_counts.head(10)
# Out:
#           word  word_count  year
# 0       design         318  2020
# 1         user         307  2020
# 2        study         216  2020
# 3       system         213  2020
# 4     research         194  2020
# 5   technology         162  2020
# 6         work         153  2020
# 7   experience         150  2020
# 8        paper         127  2020
# 9  interaction         125  2020

# %%
# Draw a nested barplot
g = sns.catplot(aspect=1.5,
    data=df_abstract_counts, kind="bar",
    x="year", y="word_count", hue="word",
    palette="dark", alpha=.6, height=6
)
g.despine(left=True)
g.set_axis_labels("Year", "Counts")
g.legend.set_title("")
g.figure.suptitle("Abstract word frequencies")
# Out:
# Text(0.5, 0.98, 'Abstract word frequencies')
